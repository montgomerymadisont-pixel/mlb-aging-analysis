# %%
# !python --version
# Out:
# Python 3.9.18

# %% [markdown]
# # MySQL connection with jupyter notebook

# %% [markdown]
# ### install mysql-connector-python

# %%
#resolving compatibility issue 
# conda create --name py3.9 python=3.9 -y

# %%
#mysql connection with python
# !conda install -c anaconda mysql-connector-python -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.3.0
#
#
#
# # All requested packages already installed.

# %% [markdown]
# ### Connection with mysql

# %%
import mysql.connector as sql
conn = sql.connect(
    host='localhost', 
    user='root', 
    password='shashi',
    database= 'zybook', # 'zybook', # 'sql_workbench',
    use_pure = True)

conn

# %%
cursor = conn.cursor(buffered=True)

# %%
#to change the database
cursor.execute("use zybook")

# %%
# install numpy, pandas and matplotlib using pip at terminal

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# SQL query to fetch data from MySQL table
query = "select * from cars_50k"

# Fetch data into DataFrame
df = pd.read_sql(query, conn)

# Close the MySQL connection
# connection.close()
# Out:
# /var/folders/6m/b17qqz3j7sv4rl14dn5672fhtjc4yy/T/ipykernel_22643/2851902694.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
df
# Out:
#        year   make                model             trim   body transmission  \
# 0      2015    Kia              Sorento               LX    SUV    automatic
# 1      2015    Kia              Sorento               LX    SUV    automatic
# 2      2014    BMW             3 Series       328i SULEV  Sedan    automatic
# 3      2015  Volvo                  S60               T5  Sedan    automatic
# 4      2014    BMW  6 Series Gran Coupe             650i  Sedan    automatic
# ...     ...    ...                  ...              ...    ...          ...
# 38193  2014   Jeep             Wrangler  Unlimited Sport    SUV    automatic
# 38194  2014   Jeep       Grand Cherokee          Limited    SUV    automatic
# 38195  2014   Jeep              Patriot            Sport    SUV    automatic
# 38196  2014   Jeep       Grand Cherokee          Limited    SUV    automatic
# 38197  2014   Jeep              Compass          Limited    SUV
#
#                      vin state  car_condition  odometer  color interior  \
# 0      5xyktca69fg566472    ca            5.0   16639.0  white    black
# 1      5xyktca69fg561319    ca            5.0    9393.0  white    beige
# 2      wba3c1c51ek116351    ca           45.0    1331.0   gray    black
# 3      yv1612tb4f1310987    ca           41.0   14282.0  white    black
# 4      wba6b2c57ed129731    ca           43.0    2641.0   gray    black
# ...                  ...   ...            ...       ...    ...      ...
# 38193  1c4bjwdg5el207568    fl            5.0    4641.0   gray    black
# 38194  1c4rjfbg4ec408475    nj           41.0   11694.0     課ﾓ    beige
# 38195  1c4njpba4ed545667    tn           42.0   34113.0     課ﾓ     gray
# 38196  1c4rjebg7ec510587    ga            5.0   17852.0  white    beige
# 38197  1c4njccb1ed683683    on           49.0   48050.0  white      tan
#
#                                        seller      mmr  sellingprice  \
# 0                     kia motors america  inc  20500.0       21500.0
# 1                     kia motors america  inc  20800.0       21500.0
# 2      financial services remarketing (lease)  31900.0       30000.0
# 3                     volvo na rep/world omni  27500.0       27750.0
# 4      financial services remarketing (lease)  66000.0       67000.0
# ...                                       ...      ...           ...
# 38193                        titan motors inc  27800.0       33800.0
# 38194                        chrysler capital  33200.0       31600.0
# 38195          enterprise veh exchange/rental  12150.0       12700.0
# 38196          economy rent a car & sales inc  28800.0       30000.0
# 38197                     chrysler canada inc  15400.0       17750.0
#
#                                       saledate
# 0      Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1      Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2      Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3      Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4      Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
# ...                                        ...
# 38193  Mon Dec 22 2014 09:30:00 GMT-0800 (PST)
# 38194  Wed Jan 14 2015 01:30:00 GMT-0800 (PST)
# 38195  Wed Dec 31 2014 10:30:00 GMT-0800 (PST)
# 38196  Tue Jan 06 2015 01:30:00 GMT-0800 (PST)
# 38197  Tue Dec 30 2014 10:00:00 GMT-0800 (PST)
#
# [38198 rows x 16 columns]
